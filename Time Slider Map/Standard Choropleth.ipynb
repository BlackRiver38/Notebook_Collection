# %%
import pandas as pd
import numpy as np
import urllib.request, json
import matplotlib
import matplotlib.pyplot as plt
import unicodedata
import folium
from folium.plugins import TimeSliderChoropleth
import geopandas as gp
import seaborn as sns

# %%
gpd = gp.read_file('all.geojson')

# %%
df = gpd['COD_COMUNA'].copy().to_frame()
df['values'] = np.random.randint(1, 20, df.shape[0])
df.head()
# Out:
#    COD_COMUNA  values
# 0        1350       2
# 1        1350       5
# 2        1310       2
# 3        1311      18
# 4        1311      18

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
m = folium.Map(location = (-33.38187075, -70.53537879464088), tiles='Stamen Toner', zoom_start = 8)

folium.Choropleth(
    geo_data = gpd,
    name = 'choropleth',
    data = df,
    columns = ['COD_COMUNA', 'values'],
    key_on='feature.properties.COD_COMUNA',
    fill_color='RdPu',
    fill_opacity=17,
    line_opacity=0.2,
    legend_name = 'TEST RANDOM DE GEOJSON'
).add_to(m)

m
# Out:
# D:\Anaconda\envs\Geopanda_Env\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
gpd2 = gp.read_file('division_comunal.shp')
gpd2.head(2)
# Out:
#                   NOM_REG NOM_PROV    NOM_COM     SHAPE_LENG  DIS_ELEC  \
# 0  Región de La Araucanía  Malleco    Ercilla  170675.595438        48
# 1  Región de La Araucanía  Malleco  Lonquimay  346907.195437        49
#
#    CIR_SENA  COD_COMUNA     SHAPE_Le_1    SHAPE_Area  \
# 0        14        9204  170675.595706  4.979025e+08
# 1        14        9205  346907.195899  3.932854e+09
#
#                                             geometry
# 0  POLYGON ((190393.220 5794527.366, 190474.419 5...
# 1  POLYGON ((294265.593 5781748.870, 294327.827 5...

# %%
gpd3 = gpd2.loc[gpd2['NOM_PROV'] == 'Santiago']
df2 = gpd3['NOM_COM'].copy().to_frame()
df2['values'] = np.random.randint(1, 20, df2.shape[0])
df2.shape
# Out:
# (32, 2)

# %%
m = folium.Map(location = (-33.38187075, -70.53537879464088), tiles='Stamen Toner', zoom_start = 9)

folium.Choropleth(
    geo_data = gpd3,
    data = df2,
    columns = ['NOM_COM', 'values'],
    key_on='properties.NOM_COM',
    fill_color='RdPu',
    fill_opacity=17,
    line_opacity=0.2,
).add_to(m)

m
# Out:
# D:\Anaconda\envs\Geopanda_Env\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
